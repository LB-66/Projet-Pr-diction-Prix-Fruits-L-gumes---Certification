# %%
import pandas as pd
import numpy as np
import requests
import time
import warnings
import os
from dotenv import load_dotenv #importer le .env où j'ai les variables d'env.
warnings.filterwarnings('ignore')

# %%
import os
os.environ["PYTHONIOENCODING"] = "utf-8"
os.environ["PGCLIENTENCODING"] = "UTF8"

# %%
df_clean = pd.read_csv('../DATA/CLEAN/fruits_legumes_enrichi.csv' , sep=';', encoding='utf-8')
